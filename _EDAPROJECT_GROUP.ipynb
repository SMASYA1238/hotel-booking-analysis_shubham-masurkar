# %% [markdown]
# <a href="https://colab.research.google.com/github/SMASYA1238/hotel-booking-analysis_shubham-masurkar/blob/main/_EDAPROJECT_GROUP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name - EDA on Hotel Booking Analysis**

# %% [markdown]
# # **Project Type - EDA**

# %% [markdown]
# # **Contribution - Group**

# %% [markdown]
# # **Name - Alpashi Sadawarti and Shubham Masurkar**

# %% [markdown]
# # **Cohort - Enlighten**

# %% [markdown]
# # **Project Summary -**
#
#
#
#
#   The hotel industry is subdivision of the hospitality industry that specializes in providing customers with lodging services. There are a variety of hotel types that typically can be categorized by size, function, service, and cost. Levels of service can usually be split into three options: limited-service, mid-range service, and full-service.
#   A hotel booking  Dataset of 119390 entries was given to perform Exploratory Data Analysis (EDA)to analyse and  find solutions from  hotel business prespective.
#
# The first step was to import and understand the data. Before importing the data, all the necessary libraries such as Numpy, Pandas, Matplotlib & Seaborn were imported. The data was imported under the variable name df and first 5 rows were viewed to comprehend the data.
# To understand each variable, the data type was checked for each variable.
#
# Further inspection of the dataset showed some null values as well as duplicated values. The duplicate values were dropped from the dataset.Also the  null values in the Dataset were taken care by replacing it with values best suited. The columns also had "zero" values, which was replaced by mean values of that particular subgroup and the dataset was ready for EDA.
#
# After the EDA, following conclusions were drawn:
#
# 1. City hotels have double the amount of reservation compared to resort hotels for same time period.
# 2. City hotels have high cancellation rates compared to Resort hotels.
# 3. Reservations for both type of hotels peak in August and is lowest in the month of January.
# 4. Majority of the reservation is by 2 adults followed by few family with 1 or 2 children.
# 5. Bookings for city hotels are higher than resort hotels by considering every years data except the year 2015.
# 6. In the year 2016 both the hotels have the highest number of guests.
# 7. Both the hotels have good occupancy in the 2nd and 3rd quarter of the year with 'August' being the highest of all.
# 8. Here we can conclude that the bookings in the month end are least. But that not true because as every month didn't have the 31 days thats why we see the less number of arrivals in the month end.
# 9. Most people prefer to stay at the hotels for upto 5 days.

# %% [markdown]
# # **GitHub Link -**
# https://github.com/ALPASHISADAWARTI/EDA_HOTEL_BOOKING_ANALYSIS.git

# %% [markdown]
# # **Problem Statement**
#
#
# 1.  What is the total count of city hotel vs resort hotel?
# 2.  What is the ratio of reservation of City hotel vs resort hotel?
# 3.  Which type of hotel have highest canellation rates?
# 4.  What is the count of Bookings Year-wise for each type of hotel?
# 5.  What is the count of Bookings month-wise for each type of hotel?
# 6.  What is the count of Bookings day of the month-wise for each type of hotel?
# 7.  Which country have highest booking count?
# 8.  What is the no of adults reserving the hotel?
# 9.  What is the no of families with children reserving the hotel?
# 10. What is the percentage of repeated guests?
# 11. How long do people prefer to stay in hotels?

# %% [markdown]
# # **Define Your Business Objective?**
#
# The objective of this EDA project is to analysis the given dataset and provide with meaningful solutions which will contribute in improving the hotel bussiness.

# %% [markdown]
# # **General Guidelines : -**
# Well-structured, formatted, and commented code is required.
#
# Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
# The additional credits will have advantages over other students during Star Student selection.
#
#     [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#               without a single error logged. ]
# Each and every logic should have proper comments.
#
# You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
# # Chart visualization code
# Why did you pick the specific chart?
# What is/are the insight(s) found from the chart?
# Will the gained insights help creating a positive business impact? Are there any insights that lead to negative growth? Justify with specific reason.
# You have to create at least 20 logical & meaningful charts having important insights.
# [ Hints : - Do the Vizualization in a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# 1. ***Know Your Data***-**done**

# %%
# Import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import datetime as dt
import matplotlib.pyplot as plt

# %%
# Import the dataset
url = '/content/drive/MyDrive/Colab Notebooks/ALMABETTER/Hotel Bookings.csv'
df = pd.read_csv(url)

# %%
# Total entries in the dataset
len(df.index)
# Out:
# 119390

# %% [markdown]
# ***2. Understanding Your Variables***- ***done***

# %%
# Checking the columns present in the data.
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
# Display dataset
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
# Datatype of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
# Systematic description of dataset
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# ***3. Data Wrangling - done***

# %%
# Find duplicated values
df[df.duplicated()].shape
# Out:
# (31994, 32)

# %%
df[df.duplicated()]
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 5       Resort Hotel            0         14               2015
# 22      Resort Hotel            0         72               2015
# 43      Resort Hotel            0         70               2015
# 138     Resort Hotel            1          5               2015
# 200     Resort Hotel            0          0               2015
# ...              ...          ...        ...                ...
# 119349    City Hotel            0        186               2017
# 119352    City Hotel            0         63               2017
# 119353    City Hotel            0         63               2017
# 119354    City Hotel            0         63               2017
# 119373    City Hotel            0        175               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 5                    July                        27
# 22                   July                        27
# ...

# %%
# Dropping duplicate values
df.drop_duplicates(inplace = True)

# %%
df.shape
# Out:
# (87396, 32)

# %%
# Sorting the null values
df.isnull().sum().sort_values(ascending=False)
# Out:
# company                           82137
# agent                             12193
# hotel                                 0
# customer_type                         0
# assigned_room_type                    0
# booking_changes                       0
# deposit_type                          0
# days_in_waiting_list                  0
# adr                                   0
# previous_bookings_not_canceled        0
# required_car_parking_spaces           0
# total_of_special_requests             0
# reservation_status                    0
# reservation_status_date               0
# Total_group_members                   0
# stays_in_weekend_and_weeks            0
# reserved_room_type                    0
# previous_cancellations                0
# is_canceled                           0
# stays_in_week_nights                  0
# lead_time                             0
# arrival_date_year                     0
# arrival_date_month                    0
# ...

# %%
# Data cleaning (dropping company and agents column)
df.drop(columns=['company','agent'],inplace=True)

# %%
# Replace the null values under this column with mean value of children.
df['children'].unique()
df['children'].fillna(df['children'].mean(), inplace = True)

# %%
#replace the missing value with the mode of 'country' column.
df['country'].fillna('others', inplace = True)

# %%
# Check if all null values are removed
df.isnull().sum().sort_values(ascending = False)[:6]
# Out:
# hotel                         0
# previous_cancellations        0
# stays_in_weekend_and_weeks    0
# Total_group_members           0
# reservation_status_date       0
# reservation_status            0
# dtype: int64

# %%
#Combine Total_group_members column for the total numbers of adults,children and babies
df['Total_group_members'] = df.adults + df.children + df.babies

# %%
#Combine stays_in_weekend_and_weeks column for the total days of stay
df['stays_in_weekend_and_weeks'] = df.stays_in_weekend_nights + df.stays_in_week_nights

# %%
# Combine day, month and year of arrival
df['arrival_date']=df['arrival_date_day_of_month'].astype(str)+ "" + df['arrival_date_month'].astype(str)+ "" + df['arrival_date_year'].astype(str)
df['arrival_date']=pd.to_datetime(df['arrival_date'])

# %%
#Adding new column for total no of guests
df['total_guests']= df['adults']+ df['children']+ df['babies']

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
# 5  Resort Hotel            0         14               2015               July
# 6  Resort Hotel            0          0               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
# 5                        27                          1
# 6                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 2                        0                     1       1  ...    No Deposit
# ...

# %% [markdown]
# ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables- done***

# %%
#1 Total count of city hotel vs resort hotel
types_of_hotel = df['hotel'].value_counts()
types_of_hotel
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-79bf6e8b847e> in <module>
#       1 #1 Total count of city hotel vs resort hotel
# ----> 2 types_of_hotel = df['hotel'].value_counts()
#       3 types_of_hotel
#
# NameError: name 'df' is not defined

# %%
#2 What is the ratio of reservation of City hotel vs resort hotel?
plt.figure(figsize = (14,8))
types_of_hotel.plot.pie(x='City Hotel', y ='Resort Hotel',autopct='%1.0f%%')
plt.legend() 
plt.show()

# %%
#3 Hotel type and cancellations
sns.set(rc={'figure.figsize':(14,12)})
graph= sns.countplot(x='hotel',hue='is_canceled',data=df)
graph.set_xlabel('Hotel Type/Cancellations',fontsize=12)
graph.set_ylabel('Reservation Count',fontsize=12)
# Out:
# Text(0, 0.5, 'Reservation Count')

# %%
#4 Count of Bookings Year-wise
sns.set(rc={'figure.figsize':(14,12)})
graph= sns.countplot(x='arrival_date_year',hue='hotel',data=df)
graph.set_xlabel('arrival_date_year',fontsize=12)
graph.set_ylabel(' Count',fontsize=12)
# Out:
# Text(0, 0.5, ' Count')

# %%
#5 Count of Bookings Month-wise
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
df['arrival_date_month'] = pd.Categorical(df['arrival_date_month'], categories=months, ordered=True)
sns.set(rc={'figure.figsize':(14,12)})
graph= sns.countplot(x='arrival_date_month',hue='hotel',data=df)
graph.set_xlabel('arrival_date_month',fontsize=12)
graph.set_ylabel(' Count',fontsize=12)
# Out:
# Text(0, 0.5, ' Count')

# %%
#6 Count of Bookings day of month wise
sns.set(rc={'figure.figsize':(14,12)})
graph= sns.countplot(x='arrival_date_day_of_month',hue='hotel',data=df,palette='Paired')
graph.set_xlabel('arrival_date_day_of_month',fontsize=12)
graph.set_ylabel(' Count',fontsize=12)
# Out:
# Text(0, 0.5, ' Count')

# %%
#7 Number of bookings country wise
country_wise_guests = df[df['is_canceled'] == 0]['country'].value_counts().reset_index()
country_wise_guests.columns = ['country', 'No of guests']
country_wise_guests
# Out:
#     country  No of guests
# 0       PRT         21071
# 1       GBR          9676
# 2       FRA          8481
# 3       ESP          6391
# 4       DEU          6069
# ..      ...           ...
# 160     BHR             1
# 161     DJI             1
# 162     MLI             1
# 163     NPL             1
# 164     FRO             1
#
# [165 rows x 2 columns]

# %%
booking_count_of_country = df['country'].value_counts().head(10)
booking_count_of_country
plt.figure(figsize = (14,8))
booking_count_of_country.plot(kind = 'bar')
plt.legend()
plt.show()

# %%
#8 What is the no of adults reserving the hotel ?
sns.set(rc={'figure.figsize':(14,12)})
graph= sns.countplot(x='adults',hue='hotel',data=df)
graph.set_xlabel('number of Adults',fontsize=12)
graph.set_ylabel('Reservation Count',fontsize=12)
# Out:
# Text(0, 0.5, 'Reservation Count')

# %%
#9 What is the no of families with children reserving the hotel?
sns.set(rc={'figure.figsize':(14,12)})
graph= sns.countplot(x='children',hue='hotel',data=df)
graph.set_xlabel('number of families with children',fontsize=12)
graph.set_ylabel('Reservation Count',fontsize=12)
# Out:
# Text(0, 0.5, 'Reservation Count')

# %%
#10 Percentage of repeated_guest
df['is_repeated_guest'].value_counts()
plt.figure(figsize = (14,8))
df['is_repeated_guest'].value_counts().plot.pie(autopct = '%1.0f%%')
plt.legend()
plt.show()

# %%
#11 How long do people stay ?
df['total_nights'] = df['stays_in_weekend_nights'] + df['stays_in_week_nights']
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  agent  company  \
# 0                        0                     0       2  ...    NaN      NaN
# ...

# %%
stay = df.groupby(['total_nights', 'hotel']).agg('count').reset_index()
stay = stay.iloc[:, :3]
stay = stay.rename(columns={'is_canceled':'Number of stays'})
stay
# Out:
#     total_nights         hotel  Number of stays
# 0              0    City Hotel              331
# 1              0  Resort Hotel              384
# 2              1    City Hotel            13272
# 3              1  Resort Hotel             7748
# 4              2    City Hotel            21426
# ..           ...           ...              ...
# 71            49    City Hotel                1
# 72            56  Resort Hotel                2
# 73            57    City Hotel                1
# 74            60  Resort Hotel                1
# 75            69  Resort Hotel                1
#
# [76 rows x 3 columns]

# %%
plt.figure(figsize = (10,5))
sns.barplot(x = 'total_nights', y = 'Number of stays',data= stay,hue='hotel')

# %% [markdown]
# ***5. Solution to Business Objective***

# %% [markdown]
# **What do you suggest the client to achieve Business Objective ?**
#
# Explain Briefly.
# 1. From the above EDA analysis it is clear that city hotels are more in demand as compared to resort hotels.
#
# 2. This low preference for resort hotels may be due to its high prices (for the luxuary they offer).
#
# 3. Overall, both types of hotels need to work on repeativity of guest and to increase the period of their stay.
#
# 3. To attract more number of customers and improve their bussiness-
# *   Resort owners may work with local bussiness Local businesses like farms, restaurants, places for activities and so on can be a great source of business.
# *  Trends are very important. Just imagine what was popular ten years ago in the hotel industry – would anyone visit that hotel? Most likely not. So, make sure that you are on top of trends.
# *   Create special packages- Build packages like the spa package, the sightseeing package, holiday packages and so on. This is convincing for the customers and often sells very well.
# *   Improve for events-Create a great space for conferences, weddings, celebrations and all kinds of different events. This is a good way to capture that high revenue clients.
# *   Also promoting their hotels on social media is a must for advertising their bussiness.

# %% [markdown]
# # ***Conclusion***
#
# After analysing almost 119000 dataset on hotel booking, it seems the city hotels and resort hotels both have scope of improvement with regards to their bussiness and serving the customers/clients.
#
# The dataset gave detailed idea about various aspect of hotel booking.By analysing this dataset, the solutions for preferrd business objective was offered.
